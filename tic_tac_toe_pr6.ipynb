# %%
 # without user input
def print_board(board):
    for row in board:
        print(" | ".join(row))
        print("-" * 5)

def check_win(board, player):
    return any(all(cell == player for cell in row) for row in board) or \
           any(all(board[i][j] == player for i in range(3)) for j in range(3)) or \
           all(board[i][i] == player for i in range(3)) or \
           all(board[i][2-i] == player for i in range(3))

def tic_tac_toe():
    board = [[' ']*3 for _ in range(3)]
    moves = [(0, 0), (1, 1), (0, 1), (2, 2), (1, 0), (2, 0), (1, 2), (0, 2), (2, 1)]  # Predefined moves
    current_player = 'X'

    for move in moves:
        row, col = move
        board[row][col] = current_player
        print_board(board)
        if check_win(board, current_player):
            print(f"Player {current_player} wins!")
            return
        current_player = 'O' if current_player == 'X' else 'X'

    print("It's a draw!")

tic_tac_toe()
# Out:
# X |   |
# -----
#   |   |
# -----
#   |   |
# -----
# X |   |
# -----
#   | O |
# -----
#   |   |
# -----
# X | X |
# -----
#   | O |
# -----
#   |   |
# -----
# X | X |
# -----
#   | O |
# -----
#   |   | O
# -----
# X | X |
# -----
# X | O |
# -----
#   |   | O
# -----
# X | X |
# -----
# X | O |
# -----
# O |   | O
# -----
# X | X |
# -----
# X | O | X
# -----
# O |   | O
# -----
# X | X | O
# -----
# X | O | X
# -----
# O |   | O
# -----
# Player O wins!

# %%
 ### Or code taking user input

def print_board(board):
    for row in board:
        print(" | ".join(row))
        print("-" * 5)

def check_winner(board, player):
    # Check rows, columns, and diagonals for a win
    for i in range(3):
        if all([cell == player for cell in board[i]]):  # Check rows
            return True
        if all([board[j][i] == player for j in range(3)]):  # Check columns
            return True

    if board[0][0] == player and board[1][1] == player and board[2][2] == player:  # Check diagonal
        return True
    if board[0][2] == player and board[1][1] == player and board[2][0] == player:  # Check reverse diagonal
        return True

    return False

def is_board_full(board):
    return all(cell != ' ' for row in board for cell in row)

def get_user_input(board, player):
    while True:
        try:
            row, col = map(int, input(f"Player {player}, enter row and column (0, 1, or 2) separated by space: ").split())
            if board[row][col] == ' ':
                return row, col
            else:
                print("Cell is already occupied. Try again.")
        except (ValueError, IndexError):
            print("Invalid input. Please enter values between 0 and 2 for row and column.")

def tic_tac_toe():
    board = [[' ']*3 for _ in range(3)]
    player = 'X'  # Starting player

    while True:
        print_board(board)
        row, col = get_user_input(board, player)
        board[row][col] = player

        if check_winner(board, player):
            print_board(board)
            print(f"Player {player} wins!")
            break
        elif is_board_full(board):
            print_board(board)
            print("It's a tie!")
            break

        player = 'O' if player == 'X' else 'X'  # Switch player

# Run the game
tic_tac_toe()
# Out:
#   |   |
# -----
#   |   |
# -----
#   |   |
# -----
# Player X, enter row and column (0, 1, or 2) separated by space: 1 2
#   |   |
# -----
#   |   | X
# -----
#   |   |
# -----
# Player O, enter row and column (0, 1, or 2) separated by space: 0
# Invalid input. Please enter values between 0 and 2 for row and column.
# Player O, enter row and column (0, 1, or 2) separated by space: 0 0
# O |   |
# -----
#   |   | X
# -----
#   |   |
# -----
# Player X, enter row and column (0, 1, or 2) separated by space: 2 2
# O |   |
# -----
#   |   | X
# -----
#   |   | X
# -----
# Player O, enter row and column (0, 1, or 2) separated by space: 1 2
# Cell is already occupied. Try again.
# Player O, enter row and column (0, 1, or 2) separated by space:  1 0
# O |   |
# -----
# O |   | X
# -----
#   |   | X
# -----
# Player X, enter row and column (0, 1, or 2) separated by space: 2 2
# Cell is already occupied. Try again.
# Player X, enter row and column (0, 1, or 2) separated by space: 0 2
# O |   | X
# -----
# O |   | X
# -----
#   |   | X
# -----
# Player X wins!
